# %% [markdown]
# # TP Pokemon première partie
#
# ## Modules necessaires
#
# * PANDAS 0.24.2  => Permet la manipulation et l'analyse de données
# * NUMPY 1.16.3   => Permet la manipulation de tableaux et matrices
#
# Dans ce TP, nous allons découvrir à travers un cas pratique les premières étapes pour mener à bien un projet de Machine Learning. Cet exemple permet d'aborder un large panel de techniques propres au Machine Learning et à l'analyse de données.
#
# ## L'univers des Pokémons
#
# Un Pokémon est un animal issu du monde des jeux vidéo. Chaque Pokémon possède des caractéristiques qui lui sont propres, à savoir son type (Pokémon d'herbe, Pokémon de feu ... ) lui donnant alors des facultés spéciales. Ainsi, le Pokémon nommé `Dracofeu`, de type `Feu` est capable de cracher du feu. De plus, on note l'existence de Pokémons légendaires très rares et très puissants (Pokémon diamant, Pokémon platine...).
#
# Les Pokémons sont également de différentes générations faisant référence à l'évolution de l'univers des Pokémons. Les Pokémons de première génération sont ceux ayant pris naissance au tout début de la création de l'univers (création de 151 Pokémons) pour arriver à la huitième génération avec plus de 800 Pokémons (2020)!
#
# Dans cet univers viennent ensuite les dresseurs de Pokémons. Les dresseurs les collectionnent et les élèvent dans le but de les faire combattre entre eux jusqu'au KO. Lors d'un combat de Pokémons, opposant deux dresseurs, l'un choisit l'animal qui sera le premier à entrer dans l'arène. En fonction de ce premier Pokémon, le second dresseur choisit un animal dans sa collection qui sera en mesure de battre le premier Pokémon. Si le premier Pokémon présent dans l'arène est de type feu, il y a de fortes chances que le Pokémon choisi par l'adversaire soit de type eau afin de contrer les attaques du premier.
#
# Cela nécessite pour le dresseur d'avoir une bonne connaissance de chaque Pokémon pour choisir celui qui pourra devenir vainqueur du combat. Pour l'aider dans son choix, les caractéristiques des Pokémons sont répertoriées dans un document appelé Pokédex.
#
# # Mission : choisir le bon Pokémon!
#
# En tant que dresseurs de Pokémon du 21e siècle, on vous demande de faire appel au Machine Learning pour faire le bon choix de Pokémon et ainsi gagner nos combats. Pour cela, vous pouvez vous appuyer sur des données en provenance du Pokédex, mais aussi sur des données issues des différents combats afin de trouver le bon modèle de prédiction qui pourra alors nous assurer une victoire lors de chaque bataille!
#
#
# # Des données pour un apprentissage supervisé
#
# ## Des données basées sur l'expérience
#
# Le Machine Learning est basé sur l'utilisation de données afin de permettre à notre ordinateur d'apprendre et de pouvoir réaliser des prédictions. Ces données doivent être en relation avec la mission qui nous est confiée et basée sur l'expérience. Dans notre cas, l'expérience consiste à connaître les issues de combats de Pokémons.
#
#
# ## Disposer d'un grand nombre de données d'apprentissage
#
# Une machine n'est pas capable d'apprendre sur un petit jeu de données, car elle doit pouvoir étudier toutes les possibilités pour réaliser ses prédictions. Par conséquent, plus le nombre de cas d'études pour résoudre un problème est important, plus les prédictions seront précises.
#
# ## Des données d'apprentissage et des données de tests
#
# Tout comme l'être humain, il est nécessaire de valider l'apprentissage de la machine afin de pouvoir corriger les écarts d'apprentissage (appelés biais) et ajuster ou modifier le modèle d'apprentissage. Pour cela, nous avons besoin de données d'apprentissage et de données de tests.
#
# # Les étapes à réaliser pour mener à bien un projet de Machine Learning
#
# Mener à bien un projet de Machine Learning consiste à réaliser six étapes consécutives :
#
# 1. Définition du problème à résoudre
# 2. Acquisition des données d'apprentissages et de tests
# 3. Préparer et nettoyer les données
# 4. Analyser, explorer les données
# 5. Choisir un modèle d'apprentissage
# 6. Visualiser les résultats, et ajuster ou modifier le modèle d'apprentissage
#
# La phase de préparation des données est la plus importante dans un projet de Machine Learning, car en tant qu'humains, nous devons essayer de trouver les données les plus intéressantes qui nous permettront de répondre au problème donné.
#
# Bien plus qu'une simple analyse des données, il faut déterminer comment il nous est possible de résoudre manuellement le problème, à partir des informations dont nous disposons, avant de le confier à la machine.
# Ainsi, un même jeu de données peut être exploité différemment en fonction du problème donné.

# %% [markdown]
# # Étape 1 : définir le problème à résoudre
#
# - Donner une défintion du problème à résoudre.
#
# - On dispose de différents pokémon ainsi que d'exemples de combat. Le but sera d'aider un dresseur de pokémon à associer le meilleur pokémon pour chaque combat qu'il aura à réaliser.

# %% [markdown]
# # Étape 2: acquérir des données d'apprentissage et de tests
#
# - Importer les librairies `OS` et `pandas`
#
# - Télécharger et copier les fichiers comportant les données nécessaires à la résolution du problème :
#     1. Le fichier Pokedex.csv contient la liste des Pokémons et leurs caractéristiques.
#     2. Le fichier Combats.csv est la base de connaissance et d'apprentissage, car il contient une liste de combats de Pokémons et le résultat de chacun d'entre eux.
#     3. Enfin, le fichier tests.csv permettra de valider le modèle d'apprentissage.
#
# - Affichier la liste des fichiers dans le repértoire du projet

# %%
import os 
import sys
sys.path.append("/home/vitcheffvi/Documents/IA/Deep_learning/venv/lib/python3.8/site-packages")
#Importer la lirairie pandas 
import pandas as pd
import numpy as np 
path="data"
data = os.listdir(path)
print(data)
# Out:
# ['pokedex.csv', 'combats.csv', 'tests.csv', 'new_pokedex.csv', 'pokedexOld.csv', 'combats copy.csv']

# %% [markdown]
# # Étape 3 : préparation des données
#
# Dans cette troisième étape, l'objectif est de réaliser une lecture approfondie des données afin de comprendre leur rôle et les impacts qu'elles peuvent avoir dans notre objectif de prédiction. C'est une sorte de résolution manuelle du problème en formulant des hypothèses et en essayant de sélectionner les données qui répondront à celles-ci.
#
# L'étude des données passe notamment par leur description (nom, type...), ainsi que par divers processus de traitement tels que le nettoyage (suppression des données inutiles, recherche des données manquantes) et enfin la combinaison entre elles, aussi appelée agrégation, dans le but de disposer d'un jeu de connaissances (observations) utilisables et appropriées à l'apprentissage et à l'atteinte de notre objectif.
#
# ## De quelles données disposons-nous?
#
# #### - Quelle est la structure des données? Les données sont organisés en fichiers. Ce sont des .csv, chaque ligne représente un pokémon. Elles sont sous la forme de tableau. Pour les combats, il s'agit de lignes qui représente chacun un combat; il y a le numéro de pokédex des pokémon qui s'affrontent ainsi que le numéro de pokédex du vainqueur.
# #### - Afficher les 10 premières lignes
# #### - Quelles sont les features de catégorisation?
# #### - Est-ce qu'il existe des données de catégorisation ordinale? Le numéro de pokédex des pokémon est une catégorisation ordinale car on associe une valeur numérique à une variable qualitative qui est le nom du pokémon.
# #### - Préciser dans un tableau le type des données.
# #### - Quel est l'intérêt de connaitre les features de catégorisation? L'intérêt est de pouvoir ensuite trier les données en fonction de ses features pour avoir des bonnes données de test ainsi que des bonnes données d'entraînement. A travers les features, on peut diviser les données en données de test et d'entraînement.
# #### - Quelles données sont de type numérique (Préciser discrètes ou continues)?  Les points de vie ainsi que d'attaque de defense ou d'attaque spéciale ou de défense sont numériques. La vitesse est aussi une variable quantitative. Toutes ces variables sont quantitatives continues. Il existe aussi des valeurs numériques mais qui ne sont pas quantitatives.
# #### - Pourquoi il est important de les connaitre? Il est important de connaître ses données pour pouvoir ensuite calculer la moyenne dessus par exemple ou pouvoir les traiter en fonction de leur type.
# #### - Que faut-il penser de la feature LEGENDAIRE? La feature legendaire = VRAI signifie qu'il n'existe un seul pokémon et que celui ci est plus fort normalement que les autres; En revanche, cela siginifie que le dresseur ne possède pas forcément ce pokémon dans sa collection.
# #### - Transformer la feature $Legendaire$ en entier 0= FAUX et 1=VRAI
# #### - Combien avons-nous d'observations?
# #### - Afficher une description des données.
# #### - Afficher les informations sur le jeu de données
# #### - Manque-t-il des données? Oui, Il manque certaines données. En effet, certains pokémons ne possèdent pas de second type car ils sont spécialisés dans un seul de leur type.
#
# ### Recherche des features manquantes
#
# ####  - Chercher le Pokemon dont le nom est manquant
# ####  - Comment traiter les observations manquantes? Le nom manquant n'est pas important car c'est le numéro de pokédex que l'on utilise dans le fichier "combat.csv". En revanche, pour les pokémons avec un seul type, cela peut influer lors de l'entraînement des données.

# %%
#Affichage des 10 premières lignes.
df = pd.read_csv(os.path.join(path,"pokedex.csv"),sep=";")
print(df.head(10))
# Out:
#    NUMERO               NOM TYPE_1  TYPE_2  POINTS_DE_VIE  POINTS_ATTAQUE  \
# 0       1        Bulbizarre  Herbe  Poison             45              49
# 1       2        Herbizarre  Herbe  Poison             60              62
# 2       3        Florizarre  Herbe  Poison             80              82
# 3       4   Mega Florizarre  Herbe  Poison             80             100
# 4       5         Salamèche    Feu     NaN             39              52
# 5       6         Reptincel    Feu     NaN             58              64
# 6       7         Dracaufeu    Feu     Vol             78              84
# 7       8  Mega Dracaufeu X    Feu  Dragon             78             130
# 8       9  Mega Dracaufeu Y    Feu     Vol             78             104
# 9      10          Carapuce    Eau     NaN             44              48
#
#    POINTS_DEFFENCE  POINTS_ATTAQUE_SPECIALE  POINT_DEFENSE_SPECIALE  \
# 0               49                       65                      65
# 1               63                       80                      80
# 2               83                      100                     100
# 3              123                      122                     120
# 4               43                       60                      50
# 5               58                       80                      65
# 6               78                      109                      85
# 7              111                      130                      85
# 8               78                      159                     115
# 9               65                       50                      64
#
#    POINTS_VITESSE  NOMBRE_GENERATIONS  LEGENDAIRE
# 0              45                   1           0
# 1              60                   1           0
# 2              80                   1           0
# 3              80                   1           0
# 4              65                   1           0
# 5              80                   1           0
# 6             100                   1           0
# 7             100                   1           0
# 8             100                   1           0
# 9              43                   1           0

# %%
#Le nombre de feature sera le nombre de colonnes 
print("Il y a "+str(len(df.axes[1]))+" features.")
# Out:
# Il y a 12 features.

# %% [markdown]
# Les features sont : <br/>
# - Le nom
# - le numéro de pokédex
# - le type du pokémon principal
# - Un second type de pokémon facultatif
# - Un nombre de points de vie
# - Un nombre de points d'attaque
# - Un nombre de points de defense
# - Un nombre de points d'attaque spéciale
# - Un nombre de points de defense spéciale
# - Un nombre de points de vitesse.
# - Le numéro de la génération du pokémon
# - Une catégorie pour détecter si c'est un pokémon légendaire

# %%
#On récupère le nom de chaque features de catégorisation. 
tabFeatures=df.columns.to_numpy()
#On recupere la première ligne du pokédex pour avoir le type de variable
premiereLigne=df.head(1).to_numpy()
#Creation du tableau avec le type de variables. 
tabvar=[]
for i in range(0,12):
  tabvar.append(type(premiereLigne[0][i]))
tabvar=np.array(tabvar)
#On met le tableau tabFeatures et tabvar ensemble pour obtenir le tableau voulu. 
tabTypeVariables=np.array([tabFeatures,tabvar])
#On affiche le tableau
for i in range(0,12):
  print("Le type de "+str(tabTypeVariables[0][i])+" est : "+str(tabTypeVariables[1][i]))
print(tabTypeVariables)
# Out:
# Le type de NUMERO est : <class 'int'>
# Le type de NOM est : <class 'str'>
# Le type de TYPE_1 est : <class 'str'>
# Le type de TYPE_2 est : <class 'str'>
# Le type de POINTS_DE_VIE est : <class 'int'>
# Le type de POINTS_ATTAQUE est : <class 'int'>
# Le type de POINTS_DEFFENCE est : <class 'int'>
# Le type de POINTS_ATTAQUE_SPECIALE est : <class 'int'>
# Le type de POINT_DEFENSE_SPECIALE est : <class 'int'>
# Le type de POINTS_VITESSE est : <class 'int'>
# Le type de NOMBRE_GENERATIONS est : <class 'int'>
# Le type de LEGENDAIRE est : <class 'int'>
# [['NUMERO' 'NOM' 'TYPE_1' 'TYPE_2' 'POINTS_DE_VIE' 'POINTS_ATTAQUE'
#   'POINTS_DEFFENCE' 'POINTS_ATTAQUE_SPECIALE' 'POINT_DEFENSE_SPECIALE'
#   'POINTS_VITESSE' 'NOMBRE_GENERATIONS' 'LEGENDAIRE']
#  [<class 'int'> <class 'str'> <class 'str'> <class 'str'> <class 'int'>
#   <class 'int'> <class 'int'> <class 'int'> <class 'int'> <class 'int'>
#   <class 'int'> <class 'int'>]]

# %%
#On transforme le fichier csv
df = pd.read_csv(os.path.join(path,"pokedex.csv"), sep=";")
df['LEGENDAIRE']=df["LEGENDAIRE"].replace("FAUX", 0)
df['LEGENDAIRE']=df["LEGENDAIRE"].replace("VRAI", 1)
df.to_csv(os.path.join(path,"pokedex.csv"),sep=";",index=False)

print(df.head(10))
# Out:
#    NUMERO               NOM TYPE_1  TYPE_2  POINTS_DE_VIE  POINTS_ATTAQUE  \
# 0       1        Bulbizarre  Herbe  Poison             45              49
# 1       2        Herbizarre  Herbe  Poison             60              62
# 2       3        Florizarre  Herbe  Poison             80              82
# 3       4   Mega Florizarre  Herbe  Poison             80             100
# 4       5         Salamèche    Feu     NaN             39              52
# 5       6         Reptincel    Feu     NaN             58              64
# 6       7         Dracaufeu    Feu     Vol             78              84
# 7       8  Mega Dracaufeu X    Feu  Dragon             78             130
# 8       9  Mega Dracaufeu Y    Feu     Vol             78             104
# 9      10          Carapuce    Eau     NaN             44              48
#
#    POINTS_DEFFENCE  POINTS_ATTAQUE_SPECIALE  POINT_DEFENSE_SPECIALE  \
# 0               49                       65                      65
# 1               63                       80                      80
# 2               83                      100                     100
# 3              123                      122                     120
# 4               43                       60                      50
# 5               58                       80                      65
# 6               78                      109                      85
# 7              111                      130                      85
# 8               78                      159                     115
# 9               65                       50                      64
#
#    POINTS_VITESSE  NOMBRE_GENERATIONS  LEGENDAIRE
# 0              45                   1           0
# 1              60                   1           0
# 2              80                   1           0
# 3              80                   1           0
# 4              65                   1           0
# 5              80                   1           0
# 6             100                   1           0
# 7             100                   1           0
# 8             100                   1           0
# 9              43                   1           0

# %%
#Afficher le nombre d'observations
print("Il y a "+str(len(df.axes[0]))+" observations.")
# Out:
# Il y a 800 observations.

# %%
#Description du jeu de données
display(df.describe())
# Out:
#          NUMERO  POINTS_DE_VIE  POINTS_ATTAQUE  POINTS_DEFFENCE  \
# count  800.0000     800.000000      800.000000       800.000000
# mean   400.5000      69.258750       79.001250        73.842500
# std    231.0844      25.534669       32.457366        31.183501
# min      1.0000       1.000000        5.000000         5.000000
# 25%    200.7500      50.000000       55.000000        50.000000
# 50%    400.5000      65.000000       75.000000        70.000000
# 75%    600.2500      80.000000      100.000000        90.000000
# max    800.0000     255.000000      190.000000       230.000000
#
#        POINTS_ATTAQUE_SPECIALE  POINT_DEFENSE_SPECIALE  POINTS_VITESSE  \
# count               800.000000              800.000000      800.000000
# mean                 72.820000               71.902500       68.277500
# std                  32.722294               27.828916       29.060474
# min                  10.000000               20.000000        5.000000
# 25%                  49.750000               50.000000       45.000000
# 50%                  65.000000               70.000000       65.000000
# 75%                  95.000000               90.000000       90.000000
# max                 194.000000              230.000000      180.000000
#
#        NOMBRE_GENERATIONS  LEGENDAIRE
# count           800.00000   800.00000
# mean              3.32375     0.08125
# std               1.66129     0.27339
# min               1.00000     0.00000
# 25%               2.00000     0.00000
# 50%               3.00000     0.00000
# 75%               5.00000     0.00000
# max               6.00000     1.00000

# %%
#Afficher les infos du jeu de données
display(df.info)
# Out:
# <bound method DataFrame.info of      NUMERO              NOM TYPE_1   TYPE_2  POINTS_DE_VIE  POINTS_ATTAQUE  \
# 0         1       Bulbizarre  Herbe   Poison             45              49
# 1         2       Herbizarre  Herbe   Poison             60              62
# 2         3       Florizarre  Herbe   Poison             80              82
# 3         4  Mega Florizarre  Herbe   Poison             80             100
# 4         5        Salamèche    Feu      NaN             39              52
# ..      ...              ...    ...      ...            ...             ...
# 795     796          Diancie  Roche      Fée             50             100
# 796     797     Mega Diancie  Roche      Fée             50             160
# 797     798    Hoopa confiné    Psy  Spectre             80             110
# 798     799    Hoopa non lié    Psy   Obscur             80             160
# 799     800        Volcanion    Feu      Eau             80             110
#
#      POINTS_DEFFENCE  POINTS_ATTAQUE_SPECIALE  POINT_DEFENSE_SPECIALE  \
# 0                 49                       65                      65
# 1                 63                       80                      80
# 2                 83                      100                     100
# 3                123                      122                     120
# 4                 43                       60                      50
# ..               ...                      ...                     ...
# 795              150                      100                     150
# 796              110                      160                     110
# 797               60                      150                     130
# 798               60                      170                     130
# 799              120                      130                      90
#
#      POINTS_VITESSE  NOMBRE_GENERATIONS  LEGENDAIRE
# 0                45                   1           0
# 1                60                   1           0
# 2                80                   1           0
# 3                80                   1           0
# 4                65                   1           0
# ..              ...                 ...         ...
# 795              50                   6           1
# 796             110                   6           1
# 797              70                   6           1
# 798              80                   6           1
# 799              70                   6           1
#
# [800 rows x 12 columns]>

# %%
#Chercher le pokémon dont le nom manque
for i in range(0,800):
  if df["NOM"].isnull()[i]:
    print("Le pokémon numéro "+str(i+1)+" n'a pas de nom.")
# Out:
# Le pokémon numéro 63 n'a pas de nom.

# %% [markdown]
# # Partie 2
#
# ##  Observations des combats

# %% [markdown]
# #### - Refaire les étapes précédentes pour analyser les observation sur les combats (fichier `combats.csv`) :
#
# - Chargement du fichier
# - Affichage des features
# - Affichage des dix premières observations
# - Classement des features: donnée catégorielle, numérique continue ou numérique discrète
# - 10 premières lignes, Comptage du nombre d'observations, affichage des informations  et recherche d'éventuelles données absentes
#
# #### - Discuter les résultats de l'analyse
#
#
# #### - Calucler le nombre de combats menés par chaque Pokémon
# Lors d'un combat, un Pokémon peut être utilisé en première position ou en seconde position.
#
# #### - Calucler le nombre de combats gagnés par chaque Pokémon
#
# #### - Faire l'assemblage des observations
#
# #### - Quel est le Pockémon qui a gagné le plus de combats?
#
# #### - Existe-t-il des Pokémons n'ayant jamais gagné?

# %%
#Recuperer le df du pokedex
df_pokedex=pd.read_csv(os.path.join(path,"pokedex.csv"),sep=";")
#Affichage des 10 premières lignes.
df = pd.read_csv(os.path.join(path,"combats.csv"),sep=",")
print(df.head(10))
#Le nombre de feature sera le nombre de colonnes 
print("Il y a "+str(len(df.columns))+" features.")
#On récupère le nom de chaque features de catégorisation. 
tabFeatures=df.columns.to_numpy()
#On recupere la première ligne du pokédex pour avoir le type de variable
premiereLigne=df.head(1).to_numpy()
#Creation du tableau avec le type de variables. 
tabvar=[]
for i in range(0,3):
  tabvar.append(type(premiereLigne[0][i]))
tabvar=np.array(tabvar)
#On met le tableau tabFeatures et tabvar ensemble pour obtenir le tableau voulu. 
tabTypeVariables=np.array([tabFeatures,tabvar])
#On affiche le tableau
for i in range(0,3):
  print("Le type de "+str(tabTypeVariables[0][i])+" est : "+str(tabTypeVariables[1][i]))
print(tabTypeVariables)
#Afficher le nombre d'observations
print("Il y a "+str(len(df.axes[0]))+" observations.")
#Description du jeu de données
display(df.describe())
#Afficher les infos du jeu de données
display(df.info)
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151
# 5            657             752     657
# 6            192             134     134
# 7             73             545     545
# 8            220             763     763
# 9            302              31      31
# Il y a 3 features.
# Le type de First_pokemon est : <class 'numpy.int64'>
# Le type de Second_pokemon est : <class 'numpy.int64'>
# Le type de Winner est : <class 'numpy.int64'>
# [['First_pokemon' 'Second_pokemon' 'Winner']
#  [<class 'numpy.int64'> <class 'numpy.int64'> <class 'numpy.int64'>]]
# Il y a 50000 observations.
#        First_pokemon  Second_pokemon        Winner
# count   50000.000000    50000.000000  50000.000000
# mean      400.495640      403.159660    408.890100
# std       229.549429      230.083644    231.159961
# min         1.000000        1.000000      1.000000
# 25%       203.000000      207.000000    206.000000
# 50%       399.000000      402.000000    422.000000
# 75%       597.250000      602.000000    606.000000
# max       800.000000      800.000000    800.000000
# <bound method DataFrame.info of        First_pokemon  Second_pokemon  Winner
# 0                266             298     298
# 1                702             701     701
# 2                191             668     668
# 3                237             683     683
# 4                151             231     151
# ...              ...             ...     ...
# 49995            707             126     707
# 49996            589             664     589
# 49997            303             368     368
# 49998            109              89     109
# 49999              9              73       9
#
# [50000 rows x 3 columns]>

# %%
#Chercher un combat sans issue ou un pokemon qui n'a pas d'id
#On cherche aussi si le pokémon sans nom est présent dans la liste des combats.
nb_absent=0 
for i in range(0,50000):
  if (df["Winner"].isnull()[i]):
    print("Il manque la valeur du vainqueur pour le combat : "+str(i))
  if (df["First_pokemon"].isnull()[i]):
    print("Il manque la valeur du premier pokémon pour le combat : "+str(i))
  if (df["Second_pokemon"].isnull()[i]):
    print("Il manque la valeur du deuxième pokémon pour le combat : "+str(i))
  if (df["First_pokemon"][i]==63) or (df["Second_pokemon"][i]==63):
    nb_absent+=1
print("Le pokémon sans nom apparaît dans "+str(nb_absent)+" combats.")
# Out:
# Le pokémon sans nom apparaît dans 108 combats.

# %%
#Calcul du nombre de combats pour chaque pokemon
#On sait qu'il y a 800 pokémons. 
for i in range(0,800):
    df_mask1=df["First_pokemon"]==i+1
    df_mask2=df["Second_pokemon"]==i+1
    filtered_df=df[df_mask1]
    filtered_df2=df[df_mask2]
    #Retrouver le nom dans le premier fichier pokedex
    infos_pokemon=df_pokedex.iloc[i]
    print(str(infos_pokemon["NOM"])+" a réalisé "+str(len(filtered_df.axes[0])+len(filtered_df2.axes[0]))+" combats.")
# Out:
# Bulbizarre a réalisé 133 combats.
# Herbizarre a réalisé 121 combats.
# Florizarre a réalisé 132 combats.
# Mega Florizarre a réalisé 125 combats.
# Salamèche a réalisé 112 combats.
# Reptincel a réalisé 118 combats.
# Dracaufeu a réalisé 133 combats.
# Mega Dracaufeu X a réalisé 139 combats.
# Mega Dracaufeu Y a réalisé 135 combats.
# Carapuce a réalisé 117 combats.
# Carabaffe a réalisé 141 combats.
# Tortank a réalisé 0 combats.
# Mega Tortank a réalisé 144 combats.
# Chenipan a réalisé 115 combats.
# Chrysacier a réalisé 133 combats.
# Papilusion a réalisé 120 combats.
# Aspicot a réalisé 111 combats.
# Coconfort a réalisé 130 combats.
# Dardargnan a réalisé 128 combats.
# Mega Dardagnan a réalisé 119 combats.
# Roucool a réalisé 126 combats.
# Roucoups a réalisé 121 combats.
# Roucarnage a réalisé 130 combats.
# Mega Roucarnage a réalisé 126 combats.
# Rattata a réalisé 135 combats.
# Rattatac a réalisé 140 combats.
# Piafabec a réalisé 138 combats.
# Rapasdepic a réalisé 123 combats.
# Abo a réalisé 131 combats.
# Arbok a réalisé 125 combats.
# Pikachu a réalisé 136 combats.
# Raichu a réalisé 121 combats.
# Sabelette a réalisé 0 combats.
# Sablaireau a réalisé 105 combats.
# Nidoran male a réalisé 119 combats.
# Nidorina a réalisé 148 combats.
# Nidoqueen a réalisé 122 combats.
# Nidoran femelle a réalisé 136 combats.
# Nidorino a réalisé 128 combats.
# Nidoking a réalisé 140 combats.
# Mélofée a réalisé 127 combats.
# Mélodelfe a réalisé 123 combats.
# Goupix a réalisé 129 combats.
# Feunard a réalisé 127 combats.
# Rondoudou a réalisé 130 combats.
# Grodoudou a réalisé 0 combats.
# Nosferapti a réalisé 145 combats.
# Nosferalto a réalisé 128 combats.
# Mystherbe a réalisé 143 combats.
# Ortide a réalisé 129 combats.
# Rafflesia a réalisé 124 combats.
# Paras a réalisé 138 combats.
# Parasect a réalisé 154 combats.
# Mimitoss a réalisé 143 combats.
# Aéromite a réalisé 140 combats.
# Taupiqueur a réalisé 126 combats.
# Triopikeur a réalisé 128 combats.
# Miaouss a réalisé 140 combats.
# Persian a réalisé 120 combats.
# Psykokwak a réalisé 142 combats.
# Akwakwak a réalisé 115 combats.
# Férosinge a réalisé 118 combats.
# nan a réalisé 108 combats.
# Caninos a réalisé 120 combats.
# Arcanin a réalisé 114 combats.
# Ptitard a réalisé 0 combats.
# Têtarte a réalisé 125 combats.
# Tartard a réalisé 130 combats.
# Abra a réalisé 108 combats.
# Kadabra a réalisé 130 combats.
# Alakazam a réalisé 140 combats.
# Mega Alakazam a réalisé 110 combats.
# Machoc a réalisé 150 combats.
# Machopeur a réalisé 124 combats.
# Mackogneur a réalisé 116 combats.
# Chétiflor a réalisé 108 combats.
# Boustiflor a réalisé 121 combats.
# Empiflor a réalisé 0 combats.
# Tentacool a réalisé 157 combats.
# Tentacruel a réalisé 117 combats.
# Racaillou a réalisé 135 combats.
# Gravalanch a réalisé 137 combats.
# Grolem a réalisé 135 combats.
# Ponyta a réalisé 115 combats.
# Galopa a réalisé 105 combats.
# Ramoloss a réalisé 122 combats.
# Flagadoss a réalisé 131 combats.
# Mega Flagadoss a réalisé 116 combats.
# Magnéti a réalisé 143 combats.
# Magnéton a réalisé 0 combats.
# Canarticho a réalisé 116 combats.
# Doduo a réalisé 134 combats.
# Dodrio a réalisé 143 combats.
# Otaria a réalisé 119 combats.
# Lamantine a réalisé 131 combats.
# Tadmorv a réalisé 142 combats.
# Grotadmorv a réalisé 133 combats.
# Kokiyas a réalisé 111 combats.
# Crustabri a réalisé 134 combats.
# Fantominus a réalisé 128 combats.
# Spectrum a réalisé 111 combats.
# Ectoplasma a réalisé 114 combats.
# Mega Ectoplasma a réalisé 131 combats.
# Onix a réalisé 135 combats.
# Soporifik a réalisé 137 combats.
# Hypnomade a réalisé 119 combats.
# Krabby a réalisé 137 combats.
# Krabboss a réalisé 112 combats.
# Voltorbe a réalisé 113 combats.
# Électrode a réalisé 129 combats.
# Noeunoeuf a réalisé 136 combats.
# Noadkoko a réalisé 95 combats.
# Osselait a réalisé 143 combats.
# Ossatueur a réalisé 120 combats.
# Kicklee a réalisé 128 combats.
# Tygnon a réalisé 140 combats.
# Excelangue a réalisé 136 combats.
# Smogo a réalisé 143 combats.
# Smogogo a réalisé 129 combats.
# Rhinocorne a réalisé 119 combats.
# Rhinoféros a réalisé 108 combats.
# Leveinard a réalisé 98 combats.
# Saquedeneu a réalisé 129 combats.
# Kangourex a réalisé 126 combats.
# Mega Kangourex a réalisé 128 combats.
# Hypotrempe a réalisé 133 combats.
# Hypocéan a réalisé 118 combats.
# Poissirène a réalisé 117 combats.
# Poissoroy a réalisé 114 combats.
# Stari a réalisé 142 combats.
# Staross a réalisé 129 combats.
# M. Mime a réalisé 136 combats.
# Insécateur a réalisé 141 combats.
# Lippoutou a réalisé 135 combats.
# Élektek a réalisé 129 combats.
# Magmar a réalisé 129 combats.
# Scarabrute a réalisé 124 combats.
# Mega Scarabrute a réalisé 121 combats.
# Tauros a réalisé 117 combats.
# Magicarpe a réalisé 139 combats.
# Léviator a réalisé 133 combats.
# Mega Léviator a réalisé 137 combats.
# Lokhlass a réalisé 139 combats.
# Métamorph a réalisé 0 combats.
# Évoli a réalisé 99 combats.
# Aquali a réalisé 132 combats.
# Voltali a réalisé 134 combats.
# Pyroli a réalisé 132 combats.
# Porygon a réalisé 128 combats.
# Amonita a réalisé 128 combats.
# Amonistar a réalisé 138 combats.
# Kabuto a réalisé 142 combats.
# Kabutops a réalisé 110 combats.
# Ptéra a réalisé 141 combats.
# Mega Ptéra a réalisé 129 combats.
# Ronflex a réalisé 112 combats.
# Artikodin a réalisé 139 combats.
# Électhor a réalisé 121 combats.
# Sulfura a réalisé 136 combats.
# Minidraco a réalisé 117 combats.
# Draco a réalisé 116 combats.
# Dracolosse a réalisé 138 combats.
# Mewtwo a réalisé 164 combats.
# Mega Mewtwo X a réalisé 135 combats.
# Mega Mewtwo Y a réalisé 125 combats.
# Mew a réalisé 113 combats.
# Germignon a réalisé 120 combats.
# Macronium a réalisé 113 combats.
# Méganium a réalisé 129 combats.
# Héricendre a réalisé 121 combats.
# Feurisson a réalisé 151 combats.
# Typhlosion a réalisé 116 combats.
# Kaiminus a réalisé 132 combats.
# Crocrodil a réalisé 136 combats.
# Aligatueur a réalisé 138 combats.
# Fouinette a réalisé 125 combats.
# Fouinar a réalisé 138 combats.
# Hoothoot a réalisé 111 combats.
# Noarfang a réalisé 136 combats.
# Coxy a réalisé 123 combats.
# Coxyclaque a réalisé 137 combats.
# Mimigal a réalisé 137 combats.
# Migalos a réalisé 0 combats.
# Nostenfer a réalisé 122 combats.
# Loupio a réalisé 114 combats.
# Lanturn a réalisé 128 combats.
# Pichu a réalisé 105 combats.
# Mélo a réalisé 112 combats.
# Toudoudou a réalisé 115 combats.
# Togepi a réalisé 122 combats.
# Togetic a réalisé 127 combats.
# Natu a réalisé 116 combats.
# Xatu a réalisé 121 combats.
# Wattouat a réalisé 140 combats.
# Lainergie a réalisé 108 combats.
# Pharamp a réalisé 119 combats.
# Mega Pharamp a réalisé 128 combats.
# Joliflor a réalisé 139 combats.
# Marill a réalisé 122 combats.
# Azumarill a réalisé 128 combats.
# Simularbre a réalisé 123 combats.
# Tarpaud a réalisé 119 combats.
# Granivol a réalisé 119 combats.
# Floravol a réalisé 119 combats.
# Cotovol a réalisé 135 combats.
# Capumain a réalisé 123 combats.
# Tournegrin a réalisé 111 combats.
# Héliatronc a réalisé 142 combats.
# Yanma a réalisé 125 combats.
# Axoloto a réalisé 125 combats.
# Maraiste a réalisé 140 combats.
# Mentali a réalisé 142 combats.
# Noctali a réalisé 127 combats.
# Cornèbre a réalisé 158 combats.
# Roigada a réalisé 132 combats.
# Feuforêve a réalisé 133 combats.
# Zarbi a réalisé 127 combats.
# Qulbutoké a réalisé 134 combats.
# Girafarig a réalisé 128 combats.
# Pomdepik a réalisé 109 combats.
# Foretress a réalisé 123 combats.
# Insolourdo a réalisé 137 combats.
# Scorplane a réalisé 134 combats.
# Steelix a réalisé 149 combats.
# Mega Steelix a réalisé 145 combats.
# Snubbull a réalisé 137 combats.
# Granbull a réalisé 119 combats.
# Qwilfish a réalisé 150 combats.
# Cizayox a réalisé 125 combats.
# Mega Cizayox a réalisé 140 combats.
# Caratroc a réalisé 135 combats.
# Scarhino a réalisé 136 combats.
# Mega Scarhino a réalisé 130 combats.
# Farfuret a réalisé 113 combats.
# Teddiursa a réalisé 109 combats.
# Ursaring a réalisé 0 combats.
# Limagma a réalisé 123 combats.
# Volcaropod a réalisé 124 combats.
# Marcacrin a réalisé 133 combats.
# Cochignon a réalisé 118 combats.
# Corayon a réalisé 139 combats.
# Rémoraid a réalisé 148 combats.
# Octillery a réalisé 113 combats.
# Cadoizo a réalisé 130 combats.
# Démanta a réalisé 131 combats.
# Airmure a réalisé 134 combats.
# Malosse a réalisé 126 combats.
# Démolosse a réalisé 139 combats.
# Mega Démolosse a réalisé 135 combats.
# Hyporoi a réalisé 136 combats.
# Phanpy a réalisé 132 combats.
# Donphan a réalisé 136 combats.
# Porygon2 a réalisé 108 combats.
# Cerfrousse a réalisé 135 combats.
# Queulorior a réalisé 138 combats.
# Debugant a réalisé 127 combats.
# Kapoera a réalisé 139 combats.
# Lippouti a réalisé 127 combats.
# Élekid a réalisé 144 combats.
# Magby a réalisé 131 combats.
# Écrémeuh a réalisé 128 combats.
# Leuphorie a réalisé 128 combats.
# Raikou a réalisé 97 combats.
# Entei a réalisé 134 combats.
# Suicune a réalisé 121 combats.
# Embrylex a réalisé 110 combats.
# Ymphect a réalisé 139 combats.
# Tyranocif a réalisé 138 combats.
# Mega Tyranocif a réalisé 124 combats.
# Lugia a réalisé 123 combats.
# Ho-Oh a réalisé 107 combats.
# Celebi a réalisé 133 combats.
# Arcko a réalisé 116 combats.
# Massko a réalisé 105 combats.
# Jungko a réalisé 122 combats.
# Mega Jungko a réalisé 126 combats.
# Poussifeu a réalisé 137 combats.
# Galifeu a réalisé 147 combats.
# Braségali a réalisé 123 combats.
# Mega Braségali a réalisé 123 combats.
# Gobou a réalisé 135 combats.
# Flobio a réalisé 148 combats.
# Laggron a réalisé 136 combats.
# Mega Laggron a réalisé 130 combats.
# Medhyèna a réalisé 114 combats.
# Grahyèna a réalisé 133 combats.
# Zigzaton a réalisé 107 combats.
# Linéon a réalisé 124 combats.
# Chenipotte a réalisé 138 combats.
# Armulys a réalisé 138 combats.
# Charmillon a réalisé 138 combats.
# Blindalys a réalisé 133 combats.
# Papinox a réalisé 139 combats.
# Nénupiot a réalisé 126 combats.
# Lombre a réalisé 127 combats.
# Ludicolo a réalisé 123 combats.
# Grainipiot a réalisé 126 combats.
# Pifeuil a réalisé 113 combats.
# Tengalice a réalisé 123 combats.
# Nirondelle a réalisé 125 combats.
# Hélédelle a réalisé 121 combats.
# Goélise a réalisé 120 combats.
# Bekipan a réalisé 124 combats.
# Tarsal a réalisé 143 combats.
# Kirlia a réalisé 136 combats.
# Gardevoir a réalisé 130 combats.
# Mega Gardevoir a réalisé 120 combats.
# Arakdo a réalisé 128 combats.
# Maskadra a réalisé 144 combats.
# Balignon a réalisé 144 combats.
# Chapignon a réalisé 130 combats.
# Parecool a réalisé 134 combats.
# Vigoroth a réalisé 134 combats.
# Monaflèmit a réalisé 150 combats.
# Ningale a réalisé 114 combats.
# Ninjask a réalisé 117 combats.
# Munja a réalisé 124 combats.
# Chuchmur a réalisé 132 combats.
# Ramboum a réalisé 143 combats.
# Brouhabam a réalisé 127 combats.
# Makuhita a réalisé 121 combats.
# Hariyama a réalisé 0 combats.
# Azurill a réalisé 135 combats.
# Tarinor a réalisé 140 combats.
# Skitty a réalisé 136 combats.
# Delcatty a réalisé 116 combats.
# Ténéfix a réalisé 121 combats.
# Mega Ténéfix a réalisé 137 combats.
# Mysdibule a réalisé 123 combats.
# Mega Mysdibule a réalisé 141 combats.
# Galekid a réalisé 126 combats.
# Galegon a réalisé 142 combats.
# Galeking a réalisé 153 combats.
# Mega Laggron a réalisé 148 combats.
# Méditikka a réalisé 139 combats.
# Charmina a réalisé 112 combats.
# Mega Charmina a réalisé 127 combats.
# Dynavolt a réalisé 136 combats.
# Élecsprint a réalisé 125 combats.
# Mega Élecsprint a réalisé 134 combats.
# Posipi a réalisé 122 combats.
# Négapi a réalisé 134 combats.
# Muciole a réalisé 111 combats.
# Lumivole a réalisé 160 combats.
# Rosélia a réalisé 116 combats.
# Gloupti a réalisé 110 combats.
# Avaltout a réalisé 121 combats.
# Carvanha a réalisé 129 combats.
# Sharpedo a réalisé 132 combats.
# Mega Sharpedo a réalisé 120 combats.
# Wailmer a réalisé 112 combats.
# Wailord a réalisé 138 combats.
# Chamallot a réalisé 120 combats.
# Camérupt a réalisé 112 combats.
# Mega Camérupt a réalisé 131 combats.
# Chartor a réalisé 125 combats.
# Spoink a réalisé 117 combats.
# Groret a réalisé 108 combats.
# Spinda a réalisé 126 combats.
# Kraknoix a réalisé 139 combats.
# Vibraninf a réalisé 124 combats.
# Libégon a réalisé 116 combats.
# Cacnea a réalisé 126 combats.
# Cacturne a réalisé 142 combats.
# Tylton a réalisé 123 combats.
# Altaria a réalisé 125 combats.
# Mega Altaria a réalisé 137 combats.
# Mangriff a réalisé 118 combats.
# Séviper a réalisé 143 combats.
# Séléroc a réalisé 130 combats.
# Solaroc a réalisé 108 combats.
# Barloche a réalisé 148 combats.
# Barbicha a réalisé 123 combats.
# Écrapince a réalisé 155 combats.
# Colhomard a réalisé 121 combats.
# Balbuto a réalisé 149 combats.
# Kaorine a réalisé 122 combats.
# Lilia a réalisé 124 combats.
# Vacilys a réalisé 128 combats.
# Anorith a réalisé 150 combats.
# Armaldo a réalisé 112 combats.
# Barpau a réalisé 123 combats.
# Milobellus a réalisé 129 combats.
# Morphéo a réalisé 121 combats.
# Kecleon a réalisé 124 combats.
# Polichombr a réalisé 136 combats.
# Branette a réalisé 139 combats.
# Mega Branette a réalisé 126 combats.
# Skelénox a réalisé 132 combats.
# Téraclope a réalisé 121 combats.
# Tropius a réalisé 134 combats.
# Éoko a réalisé 122 combats.
# Absol a réalisé 129 combats.
# Mega Absol a réalisé 139 combats.
# Okéoké a réalisé 130 combats.
# Stalgamin a réalisé 127 combats.
# Oniglali a réalisé 133 combats.
# Mega Oniglali a réalisé 92 combats.
# Obalie a réalisé 131 combats.
# Phogleur a réalisé 134 combats.
# Kaimorse a réalisé 149 combats.
# Coquiperl a réalisé 116 combats.
# Serpang a réalisé 132 combats.
# Rosabyss a réalisé 128 combats.
# Relicanth a réalisé 134 combats.
# Lovdisc a réalisé 131 combats.
# Draby a réalisé 125 combats.
# Drackhaus a réalisé 123 combats.
# Drattak a réalisé 137 combats.
# Mega Drattak a réalisé 133 combats.
# Terhal a réalisé 133 combats.
# Métang a réalisé 136 combats.
# Métalosse a réalisé 110 combats.
# Mega Métalosse a réalisé 130 combats.
# Regirock a réalisé 144 combats.
# Regice a réalisé 140 combats.
# Registeel a réalisé 113 combats.
# Latias a réalisé 133 combats.
# Mega Latias a réalisé 0 combats.
# Latios a réalisé 125 combats.
# Mega Latios a réalisé 108 combats.
# Kyogre a réalisé 128 combats.
# Kyogre primaire a réalisé 132 combats.
# Groudon a réalisé 133 combats.
# Groudon primaire a réalisé 121 combats.
# Rayquaza a réalisé 140 combats.
# Mega Rayquaza a réalisé 134 combats.
# Jirachi a réalisé 153 combats.
# Deoxys forme normale a réalisé 106 combats.
# Deoxys forme attaque a réalisé 134 combats.
# Deoxys forme défense a réalisé 151 combats.
# Deoxys forme rapide a réalisé 145 combats.
# Tortipouss a réalisé 120 combats.
# Boskara a réalisé 132 combats.
# Torterra a réalisé 113 combats.
# Ouisticram a réalisé 112 combats.
# Chimpenfeu a réalisé 123 combats.
# Simiabraz a réalisé 149 combats.
# Tiplouf a réalisé 140 combats.
# Prinplouf a réalisé 131 combats.
# Pingoléon a réalisé 123 combats.
# Étourmi a réalisé 124 combats.
# Étourvol a réalisé 119 combats.
# Étouraptor a réalisé 136 combats.
# Keunotor a réalisé 133 combats.
# Castorno a réalisé 139 combats.
# Crikzik a réalisé 124 combats.
# Mélokrik a réalisé 122 combats.
# Lixy a réalisé 139 combats.
# Luxio a réalisé 126 combats.
# Luxray a réalisé 132 combats.
# Rozbouton a réalisé 117 combats.
# Roserade a réalisé 136 combats.
# Kranidos a réalisé 102 combats.
# Charkos a réalisé 123 combats.
# Dinoclier a réalisé 125 combats.
# Bastiodon a réalisé 121 combats.
# Cheniti a réalisé 123 combats.
# Cheniselle cape de plante a réalisé 126 combats.
# Cheniselle cape de sable a réalisé 129 combats.
# Cheniselle cape de corbeille a réalisé 138 combats.
# Papilord a réalisé 135 combats.
# Apitrini a réalisé 130 combats.
# Apireine a réalisé 127 combats.
# Pachirisu a réalisé 141 combats.
# Mustébouée a réalisé 111 combats.
# Mustéflott a réalisé 124 combats.
# Ceribou a réalisé 135 combats.
# Ceriflor a réalisé 114 combats.
# Sancoki a réalisé 154 combats.
# Tritosor a réalisé 124 combats.
# Capidextre a réalisé 111 combats.
# Baudrive a réalisé 113 combats.
# Grodrive a réalisé 128 combats.
# Laporeille a réalisé 135 combats.
# Lockpin a réalisé 121 combats.
# Mega Lockpin a réalisé 129 combats.
# Magirêve a réalisé 125 combats.
# Corboss a réalisé 0 combats.
# Chaglam a réalisé 117 combats.
# Chaffreux a réalisé 119 combats.
# Korillon a réalisé 123 combats.
# Moufouette a réalisé 125 combats.
# Moufflair a réalisé 119 combats.
# Archéomire a réalisé 110 combats.
# Archéodong a réalisé 141 combats.
# Manzaï a réalisé 125 combats.
# Mime Jr. a réalisé 120 combats.
# Ptiravi a réalisé 104 combats.
# Pijako a réalisé 149 combats.
# Spiritomb a réalisé 118 combats.
# Griknot a réalisé 135 combats.
# Carmache a réalisé 133 combats.
# Carchacrok a réalisé 127 combats.
# Mega Carchacrok a réalisé 120 combats.
# Goinfrex a réalisé 118 combats.
# Riolu a réalisé 125 combats.
# Lucario a réalisé 120 combats.
# Mega Lucario a réalisé 108 combats.
# Hippopotas a réalisé 126 combats.
# Hippodocus a réalisé 120 combats.
# Rapion a réalisé 141 combats.
# Drascore a réalisé 120 combats.
# Cradopaud a réalisé 114 combats.
# Coatox a réalisé 128 combats.
# Vortente a réalisé 114 combats.
# Écayon a réalisé 131 combats.
# Luminéon a réalisé 119 combats.
# Babimanta a réalisé 108 combats.
# Blizzi a réalisé 121 combats.
# Blizzaroi a réalisé 121 combats.
# Mega Blizzaroi a réalisé 146 combats.
# Dimoret a réalisé 119 combats.
# Magnézone a réalisé 118 combats.
# Coudlangue a réalisé 129 combats.
# Rhinastoc a réalisé 104 combats.
# Bouldeneu a réalisé 125 combats.
# Élekable a réalisé 123 combats.
# Maganon a réalisé 111 combats.
# Togekiss a réalisé 126 combats.
# Yanméga a réalisé 114 combats.
# Phyllali a réalisé 151 combats.
# Givrali a réalisé 134 combats.
# Scorvol a réalisé 132 combats.
# Mammochon a réalisé 116 combats.
# Porygon-Z a réalisé 147 combats.
# Gallame a réalisé 137 combats.
# Mega Gallame a réalisé 130 combats.
# Tarinorme a réalisé 130 combats.
# Noctunoir a réalisé 136 combats.
# Momartik a réalisé 138 combats.
# Motisma a réalisé 120 combats.
# Motisma chaud a réalisé 113 combats.
# Mirosa lavage a réalisé 116 combats.
# Motisma frost a réalisé 128 combats.
# Motisma a réalisé 121 combats.
# Mitosma tondu a réalisé 134 combats.
# Créhelf a réalisé 123 combats.
# Créfollet a réalisé 133 combats.
# Créfadet a réalisé 135 combats.
# Dialga a réalisé 151 combats.
# Palkia a réalisé 149 combats.
# Heatran a réalisé 131 combats.
# Regigigas a réalisé 142 combats.
# Giratina forme modifiée a réalisé 111 combats.
# Giratina forme originale a réalisé 134 combats.
# Cresselia a réalisé 118 combats.
# Phione a réalisé 132 combats.
# Manaphy a réalisé 134 combats.
# Darkrai a réalisé 117 combats.
# Shaymin forme de terre a réalisé 136 combats.
# Shaymin forme de ciel a réalisé 118 combats.
# Arceus a réalisé 122 combats.
# Victini a réalisé 131 combats.
# Vipélierre a réalisé 111 combats.
# Lianaja a réalisé 0 combats.
# Majaspic a réalisé 132 combats.
# Gruikui a réalisé 131 combats.
# Grotichon a réalisé 144 combats.
# Roitiflam a réalisé 138 combats.
# Moustillon a réalisé 124 combats.
# Mateloutre a réalisé 122 combats.
# Clamiral a réalisé 115 combats.
# Ratentif a réalisé 135 combats.
# Miradar a réalisé 133 combats.
# Ponchiot a réalisé 100 combats.
# Ponchien a réalisé 138 combats.
# Mastouffe a réalisé 116 combats.
# Chacripan a réalisé 114 combats.
# Léopardus a réalisé 135 combats.
# Feuillajou a réalisé 130 combats.
# Feuiloutan a réalisé 131 combats.
# Flamajou a réalisé 130 combats.
# Flamoutan a réalisé 127 combats.
# Flotajou a réalisé 117 combats.
# Flotoutan a réalisé 133 combats.
# Munna a réalisé 128 combats.
# Mushana a réalisé 132 combats.
# Poichigeon a réalisé 154 combats.
# Colombeau a réalisé 124 combats.
# Déflaisan a réalisé 130 combats.
# Zébribon a réalisé 135 combats.
# Zéblitz a réalisé 107 combats.
# Nodulithe a réalisé 144 combats.
# Géolithe a réalisé 131 combats.
# Gigalithe a réalisé 148 combats.
# Chovsourir a réalisé 123 combats.
# Rhinolove a réalisé 116 combats.
# Rototaupe a réalisé 109 combats.
# Minotaupe a réalisé 133 combats.
# Nanméouïe a réalisé 133 combats.
# Mega Nanméouïe a réalisé 132 combats.
# Charpenti a réalisé 150 combats.
# Ouvrifier a réalisé 118 combats.
# Bétochef a réalisé 130 combats.
# Tritonde a réalisé 136 combats.
# Batracné a réalisé 124 combats.
# Crapustule a réalisé 119 combats.
# Judokrak a réalisé 147 combats.
# Karaclée a réalisé 136 combats.
# Larveyette a réalisé 136 combats.
# Couverdure a réalisé 123 combats.
# Manternel a réalisé 121 combats.
# Venipatte a réalisé 132 combats.
# Scobolide a réalisé 99 combats.
# Brutapode a réalisé 114 combats.
# Doudouvet a réalisé 127 combats.
# Farfaduvet a réalisé 117 combats.
# Chlorobule a réalisé 146 combats.
# Fragilady a réalisé 127 combats.
# Bargantua a réalisé 110 combats.
# Mascaïman a réalisé 134 combats.
# Escroco a réalisé 113 combats.
# Crocorible a réalisé 132 combats.
# Darumarond a réalisé 124 combats.
# Darumacho forme standard a réalisé 133 combats.
# Darumacho mode zen a réalisé 122 combats.
# Maracachi a réalisé 0 combats.
# Crabicoque a réalisé 132 combats.
# Crabaraque a réalisé 119 combats.
# Baggiguane a réalisé 109 combats.
# Baggaïd a réalisé 121 combats.
# Cryptéro a réalisé 152 combats.
# Tutafeh a réalisé 126 combats.
# Tutankafer a réalisé 122 combats.
# Carapagos a réalisé 129 combats.
# Mégapagos a réalisé 140 combats.
# Arkéapti a réalisé 118 combats.
# Aéroptéryx a réalisé 128 combats.
# Miamiasme a réalisé 117 combats.
# Miasmax a réalisé 145 combats.
# Zorua a réalisé 131 combats.
# Zoroark a réalisé 113 combats.
# Chinchidou a réalisé 148 combats.
# Pashmilla a réalisé 131 combats.
# Scrutella a réalisé 125 combats.
# Mesmérella a réalisé 123 combats.
# Sidérella a réalisé 133 combats.
# Nucléos a réalisé 129 combats.
# Méios a réalisé 124 combats.
# Symbios a réalisé 120 combats.
# Couaneton a réalisé 124 combats.
# Lakmécygne a réalisé 119 combats.
# Sorbébé a réalisé 110 combats.
# Sorboul a réalisé 126 combats.
# Sorbouboul a réalisé 125 combats.
# Vivaldaim a réalisé 119 combats.
# Haydaim a réalisé 120 combats.
# Emolga a réalisé 114 combats.
# Carabing a réalisé 121 combats.
# Lançargot a réalisé 124 combats.
# Trompignon a réalisé 120 combats.
# Gaulet a réalisé 121 combats.
# Viskuse a réalisé 132 combats.
# Moyade a réalisé 0 combats.
# Mamanbo a réalisé 132 combats.
# Statitik a réalisé 138 combats.
# Mygavolt a réalisé 137 combats.
# Grindur a réalisé 111 combats.
# Noacier a réalisé 136 combats.
# Tic a réalisé 113 combats.
# Clic a réalisé 121 combats.
# Cliticlic a réalisé 131 combats.
# Anchwatt a réalisé 126 combats.
# Lampéroie a réalisé 128 combats.
# Ohmassacre a réalisé 111 combats.
# Lewsor a réalisé 159 combats.
# Neitram a réalisé 134 combats.
# Funécire a réalisé 117 combats.
# Mélancolux a réalisé 135 combats.
# Lugulabre a réalisé 112 combats.
# Coupenotte a réalisé 135 combats.
# Incisache a réalisé 129 combats.
# Tranchodon a réalisé 127 combats.
# Polarhume a réalisé 115 combats.
# Polagriffe a réalisé 129 combats.
# Hexagel a réalisé 148 combats.
# Escargaume a réalisé 124 combats.
# Limaspeed a réalisé 128 combats.
# Limonde a réalisé 144 combats.
# Kungfouine a réalisé 130 combats.
# Shaofouine a réalisé 131 combats.
# Drakkarmin a réalisé 140 combats.
# Gringolem a réalisé 128 combats.
# Golemastoc a réalisé 126 combats.
# Scalpion a réalisé 109 combats.
# Scalproie a réalisé 141 combats.
# Frison a réalisé 119 combats.
# Furaiglon a réalisé 122 combats.
# Gueriaigle a réalisé 156 combats.
# Vostourno a réalisé 122 combats.
# Vaututrice a réalisé 147 combats.
# Aflamanoir a réalisé 121 combats.
# Fermite a réalisé 134 combats.
# Solochi a réalisé 124 combats.
# Diamat a réalisé 138 combats.
# Trioxhydre a réalisé 129 combats.
# Pyronille a réalisé 137 combats.
# Pyrax a réalisé 137 combats.
# Cobaltium a réalisé 128 combats.
# Terrakium a réalisé 123 combats.
# Viridium a réalisé 125 combats.
# Boréas forme Incarnate a réalisé 111 combats.
# Boréas forme Therian a réalisé 125 combats.
# Fulguris forme Incarnate a réalisé 125 combats.
# Fulguris forme Therian a réalisé 115 combats.
# Reshiram a réalisé 125 combats.
# Zekrom a réalisé 154 combats.
# Démétéros forme incarnée a réalisé 102 combats.
# Démétéros forme Therian a réalisé 131 combats.
# Kyurem a réalisé 128 combats.
# Kyurem noir a réalisé 100 combats.
# Kyurem blanc a réalisé 128 combats.
# Keldeo forme ordinaire a réalisé 116 combats.
# Keldeo forme resolue a réalisé 121 combats.
# Meloetta forme Aria a réalisé 142 combats.
# Meloetta forme Pirouette a réalisé 123 combats.
# Genesect a réalisé 128 combats.
# Marisson a réalisé 148 combats.
# Boguérisse a réalisé 119 combats.
# Blindépique a réalisé 124 combats.
# Feunnec a réalisé 121 combats.
# Roussil a réalisé 115 combats.
# Goupelin a réalisé 126 combats.
# Grenousse a réalisé 125 combats.
# Croâporal a réalisé 139 combats.
# Amphinobi a réalisé 127 combats.
# Sapereau a réalisé 113 combats.
# Excavarenne a réalisé 128 combats.
# Passerouge a réalisé 136 combats.
# Braisillon a réalisé 127 combats.
# Flambusard a réalisé 132 combats.
# Lépidonille a réalisé 134 combats.
# Pérégrain a réalisé 133 combats.
# Prismillon a réalisé 120 combats.
# Hélionceau a réalisé 124 combats.
# Némélios a réalisé 121 combats.
# Flabébé a réalisé 151 combats.
# Floette a réalisé 121 combats.
# Florges a réalisé 121 combats.
# Cabriolaine a réalisé 127 combats.
# Chevroum a réalisé 129 combats.
# Pandespiègle a réalisé 118 combats.
# Pandarbare a réalisé 123 combats.
# Couafarel a réalisé 131 combats.
# Psystigri a réalisé 112 combats.
# Mistigrix Male a réalisé 115 combats.
# Mistigrix Femelle a réalisé 127 combats.
# Monorpale a réalisé 112 combats.
# Dimoclès a réalisé 132 combats.
# Exagide forme de lame a réalisé 128 combats.
# Exagide forme de bouclier a réalisé 121 combats.
# Fluvetin a réalisé 133 combats.
# Cocotine a réalisé 129 combats.
# Sucroquin a réalisé 121 combats.
# Cupcanaille a réalisé 131 combats.
# Sepiatop a réalisé 110 combats.
# Sepiatroce a réalisé 158 combats.
# Opermine a réalisé 129 combats.
# Golgopathe a réalisé 134 combats.
# Venalgue a réalisé 124 combats.
# Kravarech a réalisé 156 combats.
# Flingouste a réalisé 124 combats.
# Gamblast a réalisé 147 combats.
# Galvaran a réalisé 112 combats.
# Iguolta a réalisé 120 combats.
# Ptyranidur a réalisé 107 combats.
# Rexillius a réalisé 152 combats.
# Amagara a réalisé 121 combats.
# Dragmara a réalisé 132 combats.
# Nymphali a réalisé 122 combats.
# Brutalibré a réalisé 121 combats.
# Dedenne a réalisé 124 combats.
# Strassie a réalisé 140 combats.
# Mucuscule a réalisé 117 combats.
# Colimucus a réalisé 130 combats.
# Muplodocus a réalisé 106 combats.
# Trousselin a réalisé 122 combats.
# Brocélôme a réalisé 138 combats.
# Desséliande a réalisé 150 combats.
# Pitrouille taille moyenne a réalisé 115 combats.
# Pitrouille petite taille a réalisé 0 combats.
# Pitrouille grande taille a réalisé 121 combats.
# Pitrouille super taille a réalisé 131 combats.
# Banshitrouye taille moyenne a réalisé 128 combats.
# Banshitrouye petite taille a réalisé 121 combats.
# Banshitrouye grande taille a réalisé 124 combats.
# Banshitrouye super taille a réalisé 132 combats.
# Grelaçon a réalisé 129 combats.
# Séracrawl a réalisé 121 combats.
# Sonistrelle a réalisé 127 combats.
# Bruyverne a réalisé 115 combats.
# Xerneas a réalisé 129 combats.
# Yveltal a réalisé 137 combats.
# Zygarde demi forme a réalisé 107 combats.
# Diancie a réalisé 105 combats.
# Mega Diancie a réalisé 131 combats.
# Hoopa confiné a réalisé 119 combats.
# Hoopa non lié a réalisé 144 combats.
# Volcanion a réalisé 121 combats.

# %%
#Affichage du nombre de combats gagnés par pokémon. 
for i in range(800):
    df_mask1=df["Winner"]==i+1
    filtered_df=df[df_mask1]
    #Retrouver le nom dans le premier fichier pokedex
    infos_pokemon=df_pokedex.iloc[i]
    print(str(infos_pokemon["NOM"])+" a gagné "+str(len(filtered_df.axes[0]))+" combats.")
# Out:
# Bulbizarre a gagné 37 combats.
# Herbizarre a gagné 46 combats.
# Florizarre a gagné 89 combats.
# Mega Florizarre a gagné 70 combats.
# Salamèche a gagné 55 combats.
# Reptincel a gagné 64 combats.
# Dracaufeu a gagné 115 combats.
# Mega Dracaufeu X a gagné 119 combats.
# Mega Dracaufeu Y a gagné 114 combats.
# Carapuce a gagné 19 combats.
# Carabaffe a gagné 59 combats.
# Tortank a gagné 0 combats.
# Mega Tortank a gagné 83 combats.
# Chenipan a gagné 17 combats.
# Chrysacier a gagné 13 combats.
# Papilusion a gagné 75 combats.
# Aspicot a gagné 26 combats.
# Coconfort a gagné 17 combats.
# Dardargnan a gagné 80 combats.
# Mega Dardagnan a gagné 115 combats.
# Roucool a gagné 47 combats.
# Roucoups a gagné 64 combats.
# Roucarnage a gagné 112 combats.
# Mega Roucarnage a gagné 119 combats.
# Rattata a gagné 65 combats.
# Rattatac a gagné 101 combats.
# Piafabec a gagné 62 combats.
# Rapasdepic a gagné 103 combats.
# Abo a gagné 48 combats.
# Arbok a gagné 72 combats.
# Pikachu a gagné 93 combats.
# Raichu a gagné 105 combats.
# Sabelette a gagné 0 combats.
# Sablaireau a gagné 56 combats.
# Nidoran male a gagné 20 combats.
# Nidorina a gagné 57 combats.
# Nidoqueen a gagné 66 combats.
# Nidoran femelle a gagné 34 combats.
# Nidorino a gagné 51 combats.
# Nidoking a gagné 79 combats.
# Mélofée a gagné 20 combats.
# Mélodelfe a gagné 49 combats.
# Goupix a gagné 53 combats.
# Feunard a gagné 103 combats.
# Rondoudou a gagné 15 combats.
# Grodoudou a gagné 0 combats.
# Nosferapti a gagné 55 combats.
# Nosferalto a gagné 97 combats.
# Mystherbe a gagné 9 combats.
# Ortide a gagné 28 combats.
# Rafflesia a gagné 44 combats.
# Paras a gagné 13 combats.
# Parasect a gagné 30 combats.
# Mimitoss a gagné 32 combats.
# Aéromite a gagné 92 combats.
# Taupiqueur a gagné 68 combats.
# Triopikeur a gagné 108 combats.
# Miaouss a gagné 91 combats.
# Persian a gagné 103 combats.
# Psykokwak a gagné 47 combats.
# Akwakwak a gagné 79 combats.
# Férosinge a gagné 55 combats.
# nan a gagné 85 combats.
# Caninos a gagné 54 combats.
# Arcanin a gagné 91 combats.
# Ptitard a gagné 0 combats.
# Têtarte a gagné 90 combats.
# Tartard a gagné 68 combats.
# Abra a gagné 35 combats.
# Kadabra a gagné 87 combats.
# Alakazam a gagné 108 combats.
# Mega Alakazam a gagné 86 combats.
# Machoc a gagné 21 combats.
# Machopeur a gagné 32 combats.
# Mackogneur a gagné 51 combats.
# Chétiflor a gagné 23 combats.
# Boustiflor a gagné 45 combats.
# Empiflor a gagné 0 combats.
# Tentacool a gagné 79 combats.
# Tentacruel a gagné 94 combats.
# Racaillou a gagné 16 combats.
# Gravalanch a gagné 29 combats.
# Grolem a gagné 50 combats.
# Ponyta a gagné 86 combats.
# Galopa a gagné 91 combats.
# Ramoloss a gagné 24 combats.
# Flagadoss a gagné 20 combats.
# Mega Flagadoss a gagné 16 combats.
# Magnéti a gagné 24 combats.
# Magnéton a gagné 0 combats.
# Canarticho a gagné 52 combats.
# Doduo a gagné 87 combats.
# Dodrio a gagné 121 combats.
# Otaria a gagné 29 combats.
# Lamantine a gagné 68 combats.
# Tadmorv a gagné 25 combats.
# Grotadmorv a gagné 50 combats.
# Kokiyas a gagné 21 combats.
# Crustabri a gagné 71 combats.
# Fantominus a gagné 61 combats.
# Spectrum a gagné 77 combats.
# Ectoplasma a gagné 88 combats.
# Mega Ectoplasma a gagné 113 combats.
# Onix a gagné 65 combats.
# Soporifik a gagné 30 combats.
# Hypnomade a gagné 61 combats.
# Krabby a gagné 38 combats.
# Krabboss a gagné 67 combats.
# Voltorbe a gagné 66 combats.
# Électrode a gagné 109 combats.
# Noeunoeuf a gagné 32 combats.
# Noadkoko a gagné 37 combats.
# Osselait a gagné 29 combats.
# Ossatueur a gagné 34 combats.
# Kicklee a gagné 82 combats.
# Tygnon a gagné 87 combats.
# Excelangue a gagné 19 combats.
# Smogo a gagné 20 combats.
# Smogogo a gagné 56 combats.
# Rhinocorne a gagné 34 combats.
# Rhinoféros a gagné 48 combats.
# Leveinard a gagné 15 combats.
# Saquedeneu a gagné 49 combats.
# Kangourex a gagné 95 combats.
# Mega Kangourex a gagné 107 combats.
# Hypotrempe a gagné 55 combats.
# Hypocéan a gagné 78 combats.
# Poissirène a gagné 60 combats.
# Poissoroy a gagné 55 combats.
# Stari a gagné 80 combats.
# Staross a gagné 116 combats.
# M. Mime a gagné 76 combats.
# Insécateur a gagné 124 combats.
# Lippoutou a gagné 99 combats.
# Élektek a gagné 115 combats.
# Magmar a gagné 96 combats.
# Scarabrute a gagné 81 combats.
# Mega Scarabrute a gagné 105 combats.
# Tauros a gagné 102 combats.
# Magicarpe a gagné 25 combats.
# Léviator a gagné 82 combats.
# Mega Léviator a gagné 93 combats.
# Lokhlass a gagné 61 combats.
# Métamorph a gagné 0 combats.
# Évoli a gagné 37 combats.
# Aquali a gagné 69 combats.
# Voltali a gagné 124 combats.
# Pyroli a gagné 70 combats.
# Porygon a gagné 23 combats.
# Amonita a gagné 23 combats.
# Amonistar a gagné 49 combats.
# Kabuto a gagné 61 combats.
# Kabutops a gagné 79 combats.
# Ptéra a gagné 136 combats.
# Mega Ptéra a gagné 127 combats.
# Ronflex a gagné 40 combats.
# Artikodin a gagné 95 combats.
# Électhor a gagné 93 combats.
# Sulfura a gagné 100 combats.
# Minidraco a gagné 43 combats.
# Draco a gagné 58 combats.
# Dracolosse a gagné 87 combats.
# Mewtwo a gagné 152 combats.
# Mega Mewtwo X a gagné 125 combats.
# Mega Mewtwo Y a gagné 119 combats.
# Mew a gagné 94 combats.
# Germignon a gagné 33 combats.
# Macronium a gagné 49 combats.
# Méganium a gagné 88 combats.
# Héricendre a gagné 61 combats.
# Feurisson a gagné 92 combats.
# Typhlosion a gagné 100 combats.
# Kaiminus a gagné 29 combats.
# Crocrodil a gagné 60 combats.
# Aligatueur a gagné 81 combats.
# Fouinette a gagné 9 combats.
# Fouinar a gagné 93 combats.
# Hoothoot a gagné 36 combats.
# Noarfang a gagné 68 combats.
# Coxy a gagné 28 combats.
# Coxyclaque a gagné 86 combats.
# Mimigal a gagné 13 combats.
# Migalos a gagné 0 combats.
# Nostenfer a gagné 113 combats.
# Loupio a gagné 60 combats.
# Lanturn a gagné 66 combats.
# Pichu a gagné 36 combats.
# Mélo a gagné 7 combats.
# Toudoudou a gagné 5 combats.
# Togepi a gagné 3 combats.
# Togetic a gagné 30 combats.
# Natu a gagné 64 combats.
# Xatu a gagné 88 combats.
# Wattouat a gagné 23 combats.
# Lainergie a gagné 24 combats.
# Pharamp a gagné 41 combats.
# Mega Pharamp a gagné 37 combats.
# Joliflor a gagné 30 combats.
# Marill a gagné 19 combats.
# Azumarill a gagné 44 combats.
# Simularbre a gagné 30 combats.
# Tarpaud a gagné 65 combats.
# Granivol a gagné 48 combats.
# Floravol a gagné 66 combats.
# Cotovol a gagné 114 combats.
# Capumain a gagné 87 combats.
# Tournegrin a gagné 14 combats.
# Héliatronc a gagné 23 combats.
# Yanma a gagné 90 combats.
# Axoloto a gagné 6 combats.
# Maraiste a gagné 36 combats.
# Mentali a gagné 117 combats.
# Noctali a gagné 67 combats.
# Cornèbre a gagné 130 combats.
# Roigada a gagné 32 combats.
# Feuforêve a gagné 84 combats.
# Zarbi a gagné 33 combats.
# Qulbutoké a gagné 18 combats.
# Girafarig a gagné 74 combats.
# Pomdepik a gagné 16 combats.
# Foretress a gagné 37 combats.
# Insolourdo a gagné 26 combats.
# Scorplane a gagné 93 combats.
# Steelix a gagné 25 combats.
# Mega Steelix a gagné 50 combats.
# Snubbull a gagné 21 combats.
# Granbull a gagné 35 combats.
# Qwilfish a gagné 104 combats.
# Cizayox a gagné 76 combats.
# Mega Cizayox a gagné 77 combats.
# Caratroc a gagné 0 combats.
# Scarhino a gagné 94 combats.
# Mega Scarhino a gagné 81 combats.
# Farfuret a gagné 106 combats.
# Teddiursa a gagné 26 combats.
# Ursaring a gagné 0 combats.
# Limagma a gagné 4 combats.
# Volcaropod a gagné 9 combats.
# Marcacrin a gagné 37 combats.
# Cochignon a gagné 36 combats.
# Corayon a gagné 28 combats.
# Rémoraid a gagné 69 combats.
# Octillery a gagné 37 combats.
# Cadoizo a gagné 74 combats.
# Démanta a gagné 78 combats.
# Airmure a gagné 70 combats.
# Malosse a gagné 58 combats.
# Démolosse a gagné 111 combats.
# Mega Démolosse a gagné 128 combats.
# Hyporoi a gagné 88 combats.
# Phanpy a gagné 39 combats.
# Donphan a gagné 48 combats.
# Porygon2 a gagné 53 combats.
# Cerfrousse a gagné 90 combats.
# Queulorior a gagné 52 combats.
# Debugant a gagné 17 combats.
# Kapoera a gagné 72 combats.
# Lippouti a gagné 46 combats.
# Élekid a gagné 116 combats.
# Magby a gagné 81 combats.
# Écrémeuh a gagné 103 combats.
# Leuphorie a gagné 40 combats.
# Raikou a gagné 91 combats.
# Entei a gagné 109 combats.
# Suicune a gagné 78 combats.
# Embrylex a gagné 25 combats.
# Ymphect a gagné 41 combats.
# Tyranocif a gagné 56 combats.
# Mega Tyranocif a gagné 70 combats.
# Lugia a gagné 107 combats.
# Ho-Oh a gagné 77 combats.
# Celebi a gagné 111 combats.
# Arcko a gagné 52 combats.
# Massko a gagné 76 combats.
# Jungko a gagné 113 combats.
# Mega Jungko a gagné 119 combats.
# Poussifeu a gagné 39 combats.
# Galifeu a gagné 54 combats.
# Braségali a gagné 79 combats.
# Mega Braségali a gagné 104 combats.
# Gobou a gagné 22 combats.
# Flobio a gagné 42 combats.
# Laggron a gagné 65 combats.
# Mega Laggron a gagné 77 combats.
# Medhyèna a gagné 27 combats.
# Grahyèna a gagné 85 combats.
# Zigzaton a gagné 31 combats.
# Linéon a gagné 101 combats.
# Chenipotte a gagné 10 combats.
# Armulys a gagné 3 combats.
# Charmillon a gagné 72 combats.
# Blindalys a gagné 7 combats.
# Papinox a gagné 55 combats.
# Nénupiot a gagné 10 combats.
# Lombre a gagné 36 combats.
# Ludicolo a gagné 69 combats.
# Grainipiot a gagné 11 combats.
# Pifeuil a gagné 48 combats.
# Tengalice a gagné 79 combats.
# Nirondelle a gagné 86 combats.
# Hélédelle a gagné 110 combats.
# Goélise a gagné 56 combats.
# Bekipan a gagné 59 combats.
# Tarsal a gagné 23 combats.
# Kirlia a gagné 36 combats.
# Gardevoir a gagné 84 combats.
# Mega Gardevoir a gagné 97 combats.
# Arakdo a gagné 47 combats.
# Maskadra a gagné 63 combats.
# Balignon a gagné 26 combats.
# Chapignon a gagné 67 combats.
# Parecool a gagné 15 combats.
# Vigoroth a gagné 86 combats.
# Monaflèmit a gagné 133 combats.
# Ningale a gagné 25 combats.
# Ninjask a gagné 108 combats.
# Munja a gagné 41 combats.
# Chuchmur a gagné 15 combats.
# Ramboum a gagné 37 combats.
# Brouhabam a gagné 65 combats.
# Makuhita a gagné 14 combats.
# Hariyama a gagné 0 combats.
# Azurill a gagné 13 combats.
# Tarinor a gagné 13 combats.
# Skitty a gagné 32 combats.
# Delcatty a gagné 58 combats.
# Ténéfix a gagné 49 combats.
# Mega Ténéfix a gagné 59 combats.
# Mysdibule a gagné 48 combats.
# Mega Mysdibule a gagné 53 combats.
# Galekid a gagné 28 combats.
# Galegon a gagné 36 combats.
# Galeking a gagné 63 combats.
# Mega Laggron a gagné 48 combats.
# Méditikka a gagné 45 combats.
# Charmina a gagné 82 combats.
# Mega Charmina a gagné 89 combats.
# Dynavolt a gagné 77 combats.
# Élecsprint a gagné 110 combats.
# Mega Élecsprint a gagné 123 combats.
# Posipi a gagné 92 combats.
# Négapi a gagné 81 combats.
# Muciole a gagné 76 combats.
# Lumivole a gagné 104 combats.
# Rosélia a gagné 53 combats.
# Gloupti a gagné 21 combats.
# Avaltout a gagné 45 combats.
# Carvanha a gagné 66 combats.
# Sharpedo a gagné 107 combats.
# Mega Sharpedo a gagné 114 combats.
# Wailmer a gagné 45 combats.
# Wailord a gagné 59 combats.
# Chamallot a gagné 19 combats.
# Camérupt a gagné 26 combats.
# Mega Camérupt a gagné 37 combats.
# Chartor a gagné 34 combats.
# Spoink a gagné 36 combats.
# Groret a gagné 59 combats.
# Spinda a gagné 48 combats.
# Kraknoix a gagné 41 combats.
# Vibraninf a gagné 70 combats.
# Libégon a gagné 105 combats.
# Cacnea a gagné 22 combats.
# Cacturne a gagné 66 combats.
# Tylton a gagné 36 combats.
# Altaria a gagné 82 combats.
# Mega Altaria a gagné 90 combats.
# Mangriff a gagné 79 combats.
# Séviper a gagné 61 combats.
# Séléroc a gagné 69 combats.
# Solaroc a gagné 54 combats.
# Barloche a gagné 70 combats.
# Barbicha a gagné 41 combats.
# Écrapince a gagné 22 combats.
# Colhomard a gagné 34 combats.
# Balbuto a gagné 61 combats.
# Kaorine a gagné 73 combats.
# Lilia a gagné 15 combats.
# Vacilys a gagné 26 combats.
# Anorith a gagné 81 combats.
# Armaldo a gagné 37 combats.
# Barpau a gagné 33 combats.
# Milobellus a gagné 80 combats.
# Morphéo a gagné 64 combats.
# Kecleon a gagné 34 combats.
# Polichombr a gagné 36 combats.
# Branette a gagné 74 combats.
# Mega Branette a gagné 83 combats.
# Skelénox a gagné 15 combats.
# Téraclope a gagné 21 combats.
# Tropius a gagné 56 combats.
# Éoko a gagné 52 combats.
# Absol a gagné 89 combats.
# Mega Absol a gagné 130 combats.
# Okéoké a gagné 6 combats.
# Stalgamin a gagné 39 combats.
# Oniglali a gagné 80 combats.
# Mega Oniglali a gagné 78 combats.
# Obalie a gagné 8 combats.
# Phogleur a gagné 32 combats.
# Kaimorse a gagné 75 combats.
# Coquiperl a gagné 23 combats.
# Serpang a gagné 48 combats.
# Rosabyss a gagné 37 combats.
# Relicanth a gagné 57 combats.
# Lovdisc a gagné 79 combats.
# Draby a gagné 38 combats.
# Drackhaus a gagné 43 combats.
# Drattak a gagné 113 combats.
# Mega Drattak a gagné 125 combats.
# Terhal a gagné 20 combats.
# Métang a gagné 42 combats.
# Métalosse a gagné 57 combats.
# Mega Métalosse a gagné 113 combats.
# Regirock a gagné 50 combats.
# Regice a gagné 33 combats.
# Registeel a gagné 35 combats.
# Latias a gagné 116 combats.
# Mega Latias a gagné 0 combats.
# Latios a gagné 107 combats.
# Mega Latios a gagné 97 combats.
# Kyogre a gagné 92 combats.
# Kyogre primaire a gagné 97 combats.
# Groudon a gagné 106 combats.
# Groudon primaire a gagné 91 combats.
# Rayquaza a gagné 116 combats.
# Mega Rayquaza a gagné 127 combats.
# Jirachi a gagné 134 combats.
# Deoxys forme normale a gagné 99 combats.
# Deoxys forme attaque a gagné 121 combats.
# Deoxys forme défense a gagné 112 combats.
# Deoxys forme rapide a gagné 133 combats.
# Tortipouss a gagné 14 combats.
# Boskara a gagné 39 combats.
# Torterra a gagné 39 combats.
# Ouisticram a gagné 47 combats.
# Chimpenfeu a gagné 79 combats.
# Simiabraz a gagné 136 combats.
# Tiplouf a gagné 20 combats.
# Prinplouf a gagné 33 combats.
# Pingoléon a gagné 57 combats.
# Étourmi a gagné 54 combats.
# Étourvol a gagné 75 combats.
# Étouraptor a gagné 113 combats.
# Keunotor a gagné 19 combats.
# Castorno a gagné 84 combats.
# Crikzik a gagné 11 combats.
# Mélokrik a gagné 63 combats.
# Lixy a gagné 36 combats.
# Luxio a gagné 56 combats.
# Luxray a gagné 77 combats.
# Rozbouton a gagné 33 combats.
# Roserade a gagné 94 combats.
# Kranidos a gagné 35 combats.
# Charkos a gagné 48 combats.
# Dinoclier a gagné 14 combats.
# Bastiodon a gagné 24 combats.
# Cheniti a gagné 18 combats.
# Cheniselle cape de plante a gagné 21 combats.
# Cheniselle cape de sable a gagné 22 combats.
# Cheniselle cape de corbeille a gagné 36 combats.
# Papilord a gagné 65 combats.
# Apitrini a gagné 55 combats.
# Apireine a gagné 34 combats.
# Pachirisu a gagné 103 combats.
# Mustébouée a gagné 68 combats.
# Mustéflott a gagné 112 combats.
# Ceribou a gagné 16 combats.
# Ceriflor a gagné 71 combats.
# Sancoki a gagné 18 combats.
# Tritosor a gagné 22 combats.
# Capidextre a gagné 102 combats.
# Baudrive a gagné 71 combats.
# Grodrive a gagné 80 combats.
# Laporeille a gagné 93 combats.
# Lockpin a gagné 109 combats.
# Mega Lockpin a gagné 124 combats.
# Magirêve a gagné 106 combats.
# Corboss a gagné 0 combats.
# Chaglam a gagné 71 combats.
# Chaffreux a gagné 111 combats.
# Korillon a gagné 17 combats.
# Moufouette a gagné 70 combats.
# Moufflair a gagné 85 combats.
# Archéomire a gagné 14 combats.
# Archéodong a gagné 37 combats.
# Manzaï a gagné 29 combats.
# Mime Jr. a gagné 37 combats.
# Ptiravi a gagné 8 combats.
# Pijako a gagné 111 combats.
# Spiritomb a gagné 29 combats.
# Griknot a gagné 35 combats.
# Carmache a gagné 82 combats.
# Carchacrok a gagné 97 combats.
# Mega Carchacrok a gagné 85 combats.
# Goinfrex a gagné 81 combats.
# Riolu a gagné 49 combats.
# Lucario a gagné 90 combats.
# Mega Lucario a gagné 96 combats.
# Hippopotas a gagné 30 combats.
# Hippodocus a gagné 35 combats.
# Rapion a gagné 63 combats.
# Drascore a gagné 88 combats.
# Cradopaud a gagné 29 combats.
# Coatox a gagné 85 combats.
# Vortente a gagné 28 combats.
# Écayon a gagné 68 combats.
# Luminéon a gagné 78 combats.
# Babimanta a gagné 26 combats.
# Blizzi a gagné 22 combats.
# Blizzaroi a gagné 60 combats.
# Mega Blizzaroi a gagné 62 combats.
# Dimoret a gagné 116 combats.
# Magnézone a gagné 63 combats.
# Coudlangue a gagné 35 combats.
# Rhinastoc a gagné 47 combats.
# Bouldeneu a gagné 48 combats.
# Élekable a gagné 94 combats.
# Maganon a gagné 79 combats.
# Togekiss a gagné 73 combats.
# Yanméga a gagné 91 combats.
# Phyllali a gagné 125 combats.
# Givrali a gagné 64 combats.
# Scorvol a gagné 109 combats.
# Mammochon a gagné 68 combats.
# Porygon-Z a gagné 103 combats.
# Gallame a gagné 86 combats.
# Mega Gallame a gagné 112 combats.
# Tarinorme a gagné 26 combats.
# Noctunoir a gagné 40 combats.
# Momartik a gagné 91 combats.
# Motisma a gagné 71 combats.
# Motisma chaud a gagné 79 combats.
# Mirosa lavage a gagné 90 combats.
# Motisma frost a gagné 90 combats.
# Motisma a gagné 88 combats.
# Mitosma tondu a gagné 98 combats.
# Créhelf a gagné 92 combats.
# Créfollet a gagné 79 combats.
# Créfadet a gagné 122 combats.
# Dialga a gagné 119 combats.
# Palkia a gagné 115 combats.
# Heatran a gagné 85 combats.
# Regigigas a gagné 122 combats.
# Giratina forme modifiée a gagné 74 combats.
# Giratina forme originale a gagné 89 combats.
# Cresselia a gagné 79 combats.
# Phione a gagné 74 combats.
# Manaphy a gagné 118 combats.
# Darkrai a gagné 110 combats.
# Shaymin forme de terre a gagné 117 combats.
# Shaymin forme de ciel a gagné 111 combats.
# Arceus a gagné 114 combats.
# Victini a gagné 115 combats.
# Vipélierre a gagné 51 combats.
# Lianaja a gagné 0 combats.
# Majaspic a gagné 119 combats.
# Gruikui a gagné 34 combats.
# Grotichon a gagné 55 combats.
# Roitiflam a gagné 72 combats.
# Moustillon a gagné 31 combats.
# Mateloutre a gagné 48 combats.
# Clamiral a gagné 65 combats.
# Ratentif a gagné 25 combats.
# Miradar a gagné 69 combats.
# Ponchiot a gagné 29 combats.
# Ponchien a gagné 53 combats.
# Mastouffe a gagné 72 combats.
# Chacripan a gagné 59 combats.
# Léopardus a gagné 123 combats.
# Feuillajou a gagné 53 combats.
# Feuiloutan a gagné 106 combats.
# Flamajou a gagné 60 combats.
# Flamoutan a gagné 113 combats.
# Flotajou a gagné 42 combats.
# Flotoutan a gagné 113 combats.
# Munna a gagné 5 combats.
# Mushana a gagné 9 combats.
# Poichigeon a gagné 45 combats.
# Colombeau a gagné 60 combats.
# Déflaisan a gagné 102 combats.
# Zébribon a gagné 80 combats.
# Zéblitz a gagné 100 combats.
# Nodulithe a gagné 27 combats.
# Géolithe a gagné 44 combats.
# Gigalithe a gagné 60 combats.
# Chovsourir a gagné 72 combats.
# Rhinolove a gagné 103 combats.
# Rototaupe a gagné 70 combats.
# Minotaupe a gagné 103 combats.
# Nanméouïe a gagné 46 combats.
# Mega Nanméouïe a gagné 48 combats.
# Charpenti a gagné 28 combats.
# Ouvrifier a gagné 25 combats.
# Bétochef a gagné 39 combats.
# Tritonde a gagné 62 combats.
# Batracné a gagné 54 combats.
# Crapustule a gagné 68 combats.
# Judokrak a gagné 33 combats.
# Karaclée a gagné 85 combats.
# Larveyette a gagné 35 combats.
# Couverdure a gagné 26 combats.
# Manternel a gagné 96 combats.
# Venipatte a gagné 37 combats.
# Scobolide a gagné 26 combats.
# Brutapode a gagné 106 combats.
# Doudouvet a gagné 46 combats.
# Farfaduvet a gagné 104 combats.
# Chlorobule a gagné 23 combats.
# Fragilady a gagné 91 combats.
# Bargantua a gagné 89 combats.
# Mascaïman a gagné 72 combats.
# Escroco a gagné 65 combats.
# Crocorible a gagné 111 combats.
# Darumarond a gagné 45 combats.
# Darumacho forme standard a gagné 109 combats.
# Darumacho mode zen a gagné 43 combats.
# Maracachi a gagné 0 combats.
# Crabicoque a gagné 43 combats.
# Crabaraque a gagné 40 combats.
# Baggiguane a gagné 32 combats.
# Baggaïd a gagné 61 combats.
# Cryptéro a gagné 109 combats.
# Tutafeh a gagné 27 combats.
# Tutankafer a gagné 30 combats.
# Carapagos a gagné 30 combats.
# Mégapagos a gagné 45 combats.
# Arkéapti a gagné 66 combats.
# Aéroptéryx a gagné 117 combats.
# Miamiasme a gagné 49 combats.
# Miasmax a gagné 87 combats.
# Zorua a gagné 66 combats.
# Zoroark a gagné 100 combats.
# Chinchidou a gagné 88 combats.
# Pashmilla a gagné 115 combats.
# Scrutella a gagné 26 combats.
# Mesmérella a gagné 37 combats.
# Sidérella a gagné 65 combats.
# Nucléos a gagné 4 combats.
# Méios a gagné 9 combats.
# Symbios a gagné 18 combats.
# Couaneton a gagné 45 combats.
# Lakmécygne a gagné 103 combats.
# Sorbébé a gagné 18 combats.
# Sorboul a gagné 55 combats.
# Sorbouboul a gagné 83 combats.
# Vivaldaim a gagné 70 combats.
# Haydaim a gagné 89 combats.
# Emolga a gagné 91 combats.
# Carabing a gagné 53 combats.
# Lançargot a gagné 72 combats.
# Trompignon a gagné 14 combats.
# Gaulet a gagné 25 combats.
# Viskuse a gagné 42 combats.
# Moyade a gagné 0 combats.
# Mamanbo a gagné 68 combats.
# Statitik a gagné 64 combats.
# Mygavolt a gagné 115 combats.
# Grindur a gagné 22 combats.
# Noacier a gagné 61 combats.
# Tic a gagné 12 combats.
# Clic a gagné 27 combats.
# Cliticlic a gagné 99 combats.
# Anchwatt a gagné 45 combats.
# Lampéroie a gagné 26 combats.
# Ohmassacre a gagné 34 combats.
# Lewsor a gagné 21 combats.
# Neitram a gagné 21 combats.
# Funécire a gagné 16 combats.
# Mélancolux a gagné 57 combats.
# Lugulabre a gagné 68 combats.
# Coupenotte a gagné 51 combats.
# Incisache a gagné 59 combats.
# Tranchodon a gagné 105 combats.
# Polarhume a gagné 31 combats.
# Polagriffe a gagné 48 combats.
# Hexagel a gagné 119 combats.
# Escargaume a gagné 11 combats.
# Limaspeed a gagné 118 combats.
# Limonde a gagné 29 combats.
# Kungfouine a gagné 66 combats.
# Shaofouine a gagné 121 combats.
# Drakkarmin a gagné 39 combats.
# Gringolem a gagné 40 combats.
# Golemastoc a gagné 72 combats.
# Scalpion a gagné 57 combats.
# Scalproie a gagné 86 combats.
# Frison a gagné 48 combats.
# Furaiglon a gagné 41 combats.
# Gueriaigle a gagné 108 combats.
# Vostourno a gagné 56 combats.
# Vaututrice a gagné 92 combats.
# Aflamanoir a gagné 57 combats.
# Fermite a gagné 118 combats.
# Solochi a gagné 34 combats.
# Diamat a gagné 57 combats.
# Trioxhydre a gagné 106 combats.
# Pyronille a gagné 58 combats.
# Pyrax a gagné 103 combats.
# Cobaltium a gagné 117 combats.
# Terrakium a gagné 105 combats.
# Viridium a gagné 112 combats.
# Boréas forme Incarnate a gagné 94 combats.
# Boréas forme Therian a gagné 121 combats.
# Fulguris forme Incarnate a gagné 108 combats.
# Fulguris forme Therian a gagné 99 combats.
# Reshiram a gagné 91 combats.
# Zekrom a gagné 100 combats.
# Démétéros forme incarnée a gagné 89 combats.
# Démétéros forme Therian a gagné 112 combats.
# Kyurem a gagné 99 combats.
# Kyurem noir a gagné 77 combats.
# Kyurem blanc a gagné 100 combats.
# Keldeo forme ordinaire a gagné 100 combats.
# Keldeo forme resolue a gagné 108 combats.
# Meloetta forme Aria a gagné 98 combats.
# Meloetta forme Pirouette a gagné 118 combats.
# Genesect a gagné 105 combats.
# Marisson a gagné 26 combats.
# Boguérisse a gagné 48 combats.
# Blindépique a gagné 57 combats.
# Feunnec a gagné 41 combats.
# Roussil a gagné 67 combats.
# Goupelin a gagné 104 combats.
# Grenousse a gagné 71 combats.
# Croâporal a gagné 107 combats.
# Amphinobi a gagné 122 combats.
# Sapereau a gagné 44 combats.
# Excavarenne a gagné 68 combats.
# Passerouge a gagné 55 combats.
# Braisillon a gagné 92 combats.
# Flambusard a gagné 120 combats.
# Lépidonille a gagné 11 combats.
# Pérégrain a gagné 10 combats.
# Prismillon a gagné 80 combats.
# Hélionceau a gagné 55 combats.
# Némélios a gagné 98 combats.
# Flabébé a gagné 34 combats.
# Floette a gagné 48 combats.
# Florges a gagné 76 combats.
# Cabriolaine a gagné 46 combats.
# Chevroum a gagné 62 combats.
# Pandespiègle a gagné 26 combats.
# Pandarbare a gagné 46 combats.
# Couafarel a gagné 113 combats.
# Psystigri a gagné 58 combats.
# Mistigrix Male a gagné 91 combats.
# Mistigrix Femelle a gagné 93 combats.
# Monorpale a gagné 35 combats.
# Dimoclès a gagné 44 combats.
# Exagide forme de lame a gagné 64 combats.
# Exagide forme de bouclier a gagné 63 combats.
# Fluvetin a gagné 8 combats.
# Cocotine a gagné 25 combats.
# Sucroquin a gagné 41 combats.
# Cupcanaille a gagné 81 combats.
# Sepiatop a gagné 34 combats.
# Sepiatroce a gagné 108 combats.
# Opermine a gagné 37 combats.
# Golgopathe a gagné 69 combats.
# Venalgue a gagné 14 combats.
# Kravarech a gagné 31 combats.
# Flingouste a gagné 17 combats.
# Gamblast a gagné 64 combats.
# Galvaran a gagné 59 combats.
# Iguolta a gagné 94 combats.
# Ptyranidur a gagné 34 combats.
# Rexillius a gagné 82 combats.
# Amagara a gagné 28 combats.
# Dragmara a gagné 61 combats.
# Nymphali a gagné 49 combats.
# Brutalibré a gagné 107 combats.
# Dedenne a gagné 109 combats.
# Strassie a gagné 36 combats.
# Mucuscule a gagné 25 combats.
# Colimucus a gagné 59 combats.
# Muplodocus a gagné 64 combats.
# Trousselin a gagné 70 combats.
# Brocélôme a gagné 33 combats.
# Desséliande a gagné 59 combats.
# Pitrouille taille moyenne a gagné 49 combats.
# Pitrouille petite taille a gagné 0 combats.
# Pitrouille grande taille a gagné 51 combats.
# Pitrouille super taille a gagné 33 combats.
# Banshitrouye taille moyenne a gagné 92 combats.
# Banshitrouye petite taille a gagné 98 combats.
# Banshitrouye grande taille a gagné 71 combats.
# Banshitrouye super taille a gagné 52 combats.
# Grelaçon a gagné 12 combats.
# Séracrawl a gagné 36 combats.
# Sonistrelle a gagné 40 combats.
# Bruyverne a gagné 107 combats.
# Xerneas a gagné 107 combats.
# Yveltal a gagné 111 combats.
# Zygarde demi forme a gagné 80 combats.
# Diancie a gagné 39 combats.
# Mega Diancie a gagné 116 combats.
# Hoopa confiné a gagné 60 combats.
# Hoopa non lié a gagné 89 combats.
# Volcanion a gagné 75 combats.

# %%
#Creation of a list with the summary of all the fight and the pokemon. 
name=[]
number=[]
win=[]
for i in range(800):
    df_maskW=df["Winner"]==i+1
    df_mask1=df["First_pokemon"]==i+1
    df_mask2=df["Second_pokemon"]==i+1
    #Retrouver le nom dans le premier fichier pokedex
    infos_pokemon=df_pokedex.iloc[i]
    name.append(infos_pokemon["NOM"])
    number.append(len(df[df_mask1].axes[0])+len(df[df_mask2].axes[0]))
    win.append(len(df[df_maskW].axes[0]))
summary_pokedex=np.array([name,number,win])
print(summary_pokedex)
# Out:
# [['Bulbizarre' 'Herbizarre' 'Florizarre' ... 'Hoopa confiné'
#   'Hoopa non lié' 'Volcanion']
#  ['133' '121' '132' ... '119' '144' '121']
#  ['37' '46' '89' ... '60' '89' '75']]

# %% [markdown]
# # Partie 3
#
# ## Agrégation des données avec le Pokédex
#
# Cette agrégation va nous permettre d'avoir une vue centralisée des données et de permettre une analyse plus approfondie.
#
# #### - Créer une liste comportant :
# - Les numéros des Pokémons
# - Le nombre de combats menés
# - Le nombre de combats gagnés
# - Le pourcentage de victoires par rapport au nombre de combats menés
#
# #### - Créer un nouveau Pokedex comportant les noms de Pokemons et leur victoire

# %%
#Add to the list the purcentage of victory for each pokemon
id=[]
pourcentage=[]
for i in range(800):
    id.append(i+1)
    if float(summary_pokedex[1][i])!=0:
        pourcentage.append(float(summary_pokedex[2][i])/float(summary_pokedex[1][i])*100)
    else:
        pourcentage.append(-1)

# %%
summary_pokedex=np.array([id,name,number,win,pourcentage])
print(summary_pokedex)
# Out:
# [['1' '2' '3' ... '798' '799' '800']
#  ['Bulbizarre' 'Herbizarre' 'Florizarre' ... 'Hoopa confiné'
#   'Hoopa non lié' 'Volcanion']
#  ['133' '121' '132' ... '119' '144' '121']
#  ['37' '46' '89' ... '60' '89' '75']
#  ['27.819548872180448' '38.01652892561984' '67.42424242424242' ...
#   '50.42016806722689' '61.80555555555556' '61.98347107438017']]

# %%
#Creation of a dictionnary with all the data we need 
data={
    'NUMERO':summary_pokedex[0],
    'NOM':summary_pokedex[1],
    'NOMBRE_COMBAT':summary_pokedex[2],
    'NOMBRE_VICTOIRES':summary_pokedex[3],
    'POURCENTAGE_VICTOIRE':summary_pokedex[4]
}
pokedex_combat=pd.DataFrame(data)
print(pokedex_combat)
# Out:
#     NUMERO              NOM NOMBRE_COMBAT NOMBRE_VICTOIRES  \
# 0        1       Bulbizarre           133               37
# 1        2       Herbizarre           121               46
# 2        3       Florizarre           132               89
# 3        4  Mega Florizarre           125               70
# 4        5        Salamèche           112               55
# ..     ...              ...           ...              ...
# 795    796          Diancie           105               39
# 796    797     Mega Diancie           131              116
# 797    798    Hoopa confiné           119               60
# 798    799    Hoopa non lié           144               89
# 799    800        Volcanion           121               75
#
#     POURCENTAGE_VICTOIRE
# 0     27.819548872180448
# 1      38.01652892561984
# 2      67.42424242424242
# 3      56.00000000000001
# 4     49.107142857142854
# ..                   ...
# 795   37.142857142857146
# 796    88.54961832061069
# 797    50.42016806722689
# 798    61.80555555555556
# 799    61.98347107438017
#
# [800 rows x 5 columns]

# %%
#Save the pokedex in a .csv file
pokedex_combat.to_csv("data/new_pokedex.csv")
